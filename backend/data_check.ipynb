# %%
import numpy as np 
import pandas as pd

# %%
file_path = 'D:\\Hackathon\\IITD_INDRA\\Indra_Database.csv'

# %%
data = pd.read_csv(file_path)
data.head()
# Out:
# C:\Users\sourav\AppData\Local\Temp\ipykernel_1900\2076584778.py:1: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
#    pincode    officename                District      State   latitude  \
# 0   504273  Kothimir B.O  KUMURAM BHEEM ASIFABAD  TELANGANA  19.363869
# 1   504299  Papanpet B.O  KUMURAM BHEEM ASIFABAD  TELANGANA   19.47649
# 2   504299    Kukuda B.O  KUMURAM BHEEM ASIFABAD  TELANGANA        NaN
# 3   504296  Bareguda B.O  KUMURAM BHEEM ASIFABAD  TELANGANA  19.328575
# 4   504296     Mosam B.O  KUMURAM BHEEM ASIFABAD  TELANGANA  19.377804
#
#    longitude  Monsoon (Jun-Sep)  Post-Monsoon (Oct-Dec)  \
# 0  79.537666                NaN                     NaN
# 1  79.583923                NaN                     NaN
# 2        NaN                NaN                     NaN
# 3  79.476013                NaN                     NaN
# 4  79.616521                NaN                     NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165627 entries, 0 to 165626
# Data columns (total 20 columns):
#  #   Column                                                                   Non-Null Count   Dtype
# ---  ------                                                                   --------------   -----
#  0   pincode                                                                  165627 non-null  int64
#  1   officename                                                               165627 non-null  object
#  2   District                                                                 165627 non-null  object
#  3   State                                                                    165627 non-null  object
#  4   latitude                                                                 153620 non-null  object
#  5   longitude                                                                153625 non-null  object
# ...
